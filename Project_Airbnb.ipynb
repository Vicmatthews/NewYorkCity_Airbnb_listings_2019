# %%
cd
# Out:
# C:\Users\HP

# %% [markdown]
# ## Importing the required libraries.

# %%
import pandas as pd
import numpy as np
import pandas_profiling
from tqdm.notebook import tqdm
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Downloads/AB_NYC_2019.csv", low_memory=False)

# %%
#checking the total rows and columns
df.shape
# Out:
# (48895, 16)

# %%
# checking the first 5 rows
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#to generate a profile report for the data frame
df.profile_report()

# %%
#checking for null values
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#df.last_review.value_counts()
# Out:
# 2019-06-23    1413
# 2019-07-01    1359
# 2019-06-30    1341
# 2019-06-24     875
# 2019-07-07     718
#               ...
# 2014-05-05       1
# 2017-11-03       1
# 2013-03-08       1
# 2015-09-20       1
# 2015-01-11       1
# Name: last_review, Length: 1764, dtype: int64

# %%
#last review and reviews per month would be dropped. They has so many missing values and are not so important for our work
df1= df[['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count',
       'availability_365']]

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#checking the data types
df1.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
#checking for null values
df1.isna().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
# checking where name is null
df1.loc[df1["name"].isnull()]
# Out:
#              id name   host_id host_name neighbourhood_group  \
# 2854    1615764  NaN   6676776     Peter           Manhattan
# 3703    2232600  NaN  11395220      Anna           Manhattan
# 5775    4209595  NaN  20700823     Jesse           Manhattan
# 5975    4370230  NaN  22686810   Michaël           Manhattan
# 6269    4581788  NaN  21600904     Lucie            Brooklyn
# 6567    4756856  NaN   1832442  Carolina            Brooklyn
# 6605    4774658  NaN  24625694      Josh           Manhattan
# 8841    6782407  NaN  31147528  Huei-Yin            Brooklyn
# 11963   9325951  NaN  33377685  Jonathan           Manhattan
# 12824   9787590  NaN  50448556    Miguel           Manhattan
# 13059   9885866  NaN  37306329  Juliette           Manhattan
# 13401  10052289  NaN  49522403   Vanessa            Brooklyn
# 15819  12797684  NaN  69715276       Yan           Manhattan
# 16071  12988898  NaN  71552588    Andrea               Bronx
# ...

# %%
# replacing null values in the "name" with "unspecified" 
df1.loc[df1["name"].isnull(), "name"] = "unspecified"
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# replacing null value in the "host name" with "Anonymous" 
df1.loc[df1["host_name"].isnull(), "host_name"] = "Anonymous"

# %%
df1.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df1.profile_report()

# %%
# checking where price=0
df1.loc[(df1["price"] == 0)]
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
# ...

# %%
df1.loc[(df1["host_name"] == "Kimberly") & (df1["neighbourhood_group"]=="Brooklyn")]

# %%
df1["minimum_nights"].value_counts()
# Out:
# 1       12720
# 2       11696
# 3        7999
# 30       3760
# 4        3303
#         ...
# 42          1
# 186         1
# 265         1
# 1000        1
# 364         1
# Name: minimum_nights, Length: 109, dtype: int64

# %%
#"minimum night should reasonable not have so high values. We would replace any value above the mean with the mean (7)
df1.loc[df1["minimum_nights"] > 6, "minimum_nights"] = 7
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df1["minimum_nights"].value_counts()
# Out:
# 1    12720
# 2    11696
# 7     9391
# 3     7999
# 4     3303
# 5     3034
# 6      752
# Name: minimum_nights, dtype: int64

# %%
df1["availability_365"].value_counts()
# Out:
# 0      17533
# 365     1295
# 364      491
# 1        408
# 89       361
#        ...
# 195       26
# 196       24
# 183       24
# 181       23
# 202       20
# Name: availability_365, Length: 366, dtype: int64

# %%
#availability in the year cannot possibly be 0, so we replace with 1
df1.loc[df1["availability_365"] ==0, "availability_365"] = 1

# %%
df1["availability_365"].value_counts()
# Out:
# 1      17941
# 365     1295
# 364      491
# 89       361
# 5        340
#        ...
# 195       26
# 183       24
# 196       24
# 181       23
# 202       20
# Name: availability_365, Length: 365, dtype: int64

# %%
#drop the 11 rows where price = 0
df1.drop(df1.index[df1["price"] == 0], inplace = True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.neighbourhood.value_counts()
# Out:
# Williamsburg          3919
# Bedford-Stuyvesant    3710
# Harlem                2658
# Bushwick              2462
# Upper West Side       1971
#                       ...
# Rossville                1
# New Dorp                 1
# Richmondtown             1
# Woodrow                  1
# Fort Wadsworth           1
# Name: neighbourhood, Length: 221, dtype: int64

# %%
df1.neighbourhood.value_counts().keys()
# Out:
# Index(['Williamsburg', 'Bedford-Stuyvesant', 'Harlem', 'Bushwick',
#        'Upper West Side', 'Hell's Kitchen', 'East Village', 'Upper East Side',
#        'Crown Heights', 'Midtown',
#        ...
#        'Westerleigh', 'Bay Terrace, Staten Island', 'West Farms',
#        'Howland Hook', 'Willowbrook', 'Rossville', 'New Dorp', 'Richmondtown',
#        'Woodrow', 'Fort Wadsworth'],
#       dtype='object', length=221)

# %%
df1.neighbourhood_group.value_counts().keys()
# Out:
# Index(['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'], dtype='object')

# %%
df_copy.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# saving the final dataframe to a csv so it can be use for Exploratory analysis.
df1.to_csv("Downloads/airbnb.csv")
